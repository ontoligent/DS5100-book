# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(100,4))

# %%
df
# Out:
#            0         1         2         3
# 0   0.812434 -1.696022  1.660218  0.629914
# 1   1.655244 -0.918092  0.952138  0.163962
# 2  -0.002438  1.464600 -0.518746 -1.647287
# 3   0.950740 -0.013377 -0.517646  2.720831
# 4  -0.531688 -0.226003  1.722747 -0.079758
# ..       ...       ...       ...       ...
# 95  0.261878  0.593952 -0.259741 -0.585040
# 96  0.466255 -0.587208 -0.718437 -0.821890
# 97 -0.975510 -1.382406 -1.748368  0.992071
# 98 -0.958367 -0.675104 -1.118253  0.854418
# 99 -1.242094 -0.454239 -1.076605 -0.086003
#
# [100 rows x 4 columns]

# %%
df.unstack().to_frame().plot(figsize=(10,2), legend=False);
