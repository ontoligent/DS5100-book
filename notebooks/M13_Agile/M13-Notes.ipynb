# %% [markdown]
# # M13 Notes

# %% [markdown]
# # Business
#
# - Final Projects are **due Sunday night** (5 May). No late assignments will be accepted.
# - The Final Exam will be available from **Friday through Thursday** (3–10 May).
# - No office hours&mdash;message me with questions.

# %% [markdown]
# # Correction
#
# - The analogy I made between Jupyter Lab and RStudio missed the point!
#   - The question was about comparing Jupyter notebooks (`.ipynb` files) and R Markdown files (`.Rmd`).
#   - Both RStudio and Jupyter Lab are IDEs.
#   - But Jupyter notebooks and R Markdown files have strengths and weaknesses.
#   - One big difference is that Jupyter notebooks can only run one language, while R Markdown can run several.
#   - Jupyter notebooks have a drag-and-drop interface while R Markdown files rely on cut-and-paste.

# %% [markdown]
# # Agile
#
# ![image.png](attachment:dd5eca05-0a2b-41d0-9912-40d74346da92.png)
#
# - Part of the DS domain of **practice**
# - **Agile** has a history of being a reaction to more bureucratic methods of software development
# - Was invented to introduce more flexibility and responsiveness to the process
# - A key element of the approach is/was **user stories**

# %% [markdown]
# # Question
#
# - What is the iron triangle?
# - What is a non-functional requirement?
# - What are your experiences with project management?

# %% [markdown]
# ```python
#
# x = foo()
# ```
#
# ```bash
# ls -l foo
# ```
#
# ```r
# a <- foo()
# ```
